# %% [markdown]
# ## Proyecto integrador

# %%
#pip install clean-text

# %%
from cleantext import clean
import ftfy
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# ### Lectura de datos

# %%
import pandas as pd

# Leer el archivo CSV
df = pd.read_csv('Data/Busqueda_1.csv', encoding='ISO-8859-1')  # Usamos la codificación ISO-8859-1 que es común para archivos CSV con errores de codificación

df
# Out:
#              ASIN                                       Product Name  \
# 0      B0BY7R11JB  Rebar-Stakes-12-Inch-Galvanized  J Hook Rebar ...
# 1      B0BYZPBF3L  CozeCube Light Beige Bath mats for Bathroom No...
# 2      B0C3GRT1Q3  PURPLE LADYBUG Scratch Art for Kids - Party Fa...
# 3      B0CL9X56BK  Cordless Long Handle Replacement Brush Heads f...
# 4      B0C1FY79XG  Fitwarm Cheerleader Dog Costume  Sporty Cheer ...
# ...           ...                                                ...
# 10199  B0CHMK5L2R  INPAKSA Women's Slippers Platform Mini Boots S...
# 10200  B07QQX6JVL  SEPARO Spandex Table Cover Fitted Rectangular ...
# 10201  B0BLJJNFYN  HYC00 Travel Duffel Bag Sports Tote Gym/Should...
# 10202  B0CFKGY6XH  FREE VILLAGE Ice Makers Countertop Nugget Cube...
# 10203  B0CJJZYR9Y  DRMTLGY Brightening Eye Masks - Caffeine Eye M...
#
#                 Brand                   Category Est. Monthly Revenue  \
# 0              QNLONG       Patio, Lawn & Garden           $15,001.20
# 1            CozeCube             Home & Kitchen           $15,001.35
# 2      PURPLE LADYBUG               Toys & Games           $15,004.31
# 3               Bilim         Health & Household           $15,004.98
# 4             Fitwarm               Pet Supplies           $15,004.99
# ...               ...                        ...                  ...
# 10199         INPAKSA  Clothing, Shoes & Jewelry          $520,217.72
# 10200          SEPARO           Kitchen & Dining          $520,702.56
# 10201           HYC00  Clothing, Shoes & Jewelry          $520,906.40
# 10202    FREE VILLAGE                 Appliances          $521,539.94
# 10203         DRMTLGY     Beauty & Personal Care          $522,879.00
#
#       Est. Monthly Sales    Price    Fees     Net    Rank    Reviews  LQS  \
# 0                  1,080   $13.89    N.A.    N.A.   1,381  43.000000    6
# 1                  1,365   $24.99    N.A.    N.A.  23,336  43.135135    7
# 2                  1,669    $8.99    N.A.    N.A.   7,824   5.000000    6
# 3                  1,502    $9.99    N.A.    N.A.    N.A.  21.000000    5
# 4                  1,001   $14.99   $5.79   $9.20   5,053  30.000000    6
# ...                  ...      ...     ...     ...     ...        ...  ...
# 10199             11,314   $45.98    N.A.    N.A.   1,113  32.000000    7
# 10200              9,648   $53.97    N.A.    N.A.     524   2.000000    7
# 10201             13,360   $38.99  $12.58  $26.41  74,253  12.000000    7
# 10202              2,006  $259.99    N.A.    N.A.   2,907  10.000000    7
# 10203             10,671   $49.00  $11.12  $37.88   1,221   4.000000    6
#
#        Sellers Date First Available                             Buy Box Owner  \
# 0            1           05/27/2023                                    Amazon
# 1            2           03/19/2023  taianshiyujiadianzishangmaoyouxiangongsi
# 2            1           06/28/2023                                    Amazon
# 3            1           06/18/2023                                    Amazon
# 4            1           04/03/2023                                    Amazon
# ...        ...                  ...                                       ...
# 10199        1           09/07/2023                                  INPAKSAS
# 10200        1           06/24/2023                                    Amazon
# 10201        3           12/17/2022                          Amazon Warehouse
# 10202        1           08/15/2023                                progressUS
# 10203        2           10/03/2023                                      N.A.
#
#        Rating               Dimensions         Product Tier    Weight
# 0         4.8                     N.A.                 N.A.      N.A.
# 1         3.9                     N.A.                 N.A.      N.A.
# 2         5.0                     N.A.                 N.A.      N.A.
# 3         5.0                     N.A.                 N.A.      N.A.
# 4         4.3   12.87" x 9.80" x 0.87"  Large standard-size   2.4 lbs
# ...       ...                      ...                  ...       ...
# 10199     3.9                     N.A.                 N.A.      N.A.
# 10200     5.0                     N.A.                 N.A.      N.A.
# 10201     4.4  12.99" x 10.28" x 4.33"  Large standard-size  2.05 lbs
# 10202     3.5  11.30" x 8.66" x 12.68"                 N.A.      N.A.
# 10203     5.0    3.62" x 3.35" x 1.73"  Large standard-size  6.35 lbs
#
# [10204 rows x 19 columns]

# %% [markdown]
# ## Limpieza de lso datos

# %%
df = df.drop_duplicates(subset='ASIN')

# %%
df = df.drop(columns=['ASIN', 'Fees', 'Net', 'Dimensions', 'Product Tier', 'Weight' ])

# %%
import pandas as pd
import ftfy

# Función para limpiar texto
def clean_text(text):
    fixed_text = ftfy.fix_text(text)
    cleaned_text = clean(fixed_text, 
                         fix_unicode=True,
                         to_ascii=True,
                         no_line_breaks=True,
                         no_urls=True,
                         no_emails=True,
                         no_phone_numbers=True,
                         no_numbers=False,
                         no_digits=False,
                         no_currency_symbols=True,
                         no_punct=True,
                         replace_with_punct="",
                         lang="en")
    return cleaned_text

text_columns = ['Product Name', 'Brand', 'Category', 'Buy Box Owner']

# Verificar valores faltantes
for col in text_columns:
    df[col] = df[col].astype(str).apply(clean_text)

    
df.replace("N.A.", np.nan, inplace=True)
df.replace("na", np.nan, inplace=True)

missing_values = df.isnull().sum()

# Verificar valores faltantes
missing_values = df.isnull().sum()
print("Missing values per column:\n", missing_values)
# Out:
# Missing values per column:
#  Product Name                0
# Category                    0
# Brand                       0
# Rank                     1297
# Reviews                     0
# LQS                         0
# Sellers                     0
# Date First Available        0
# Time in Market (days)       0
# Buy Box Owner               0
# Rating                      0
# Price                       0
# Est. Monthly Sales         53
# Est. Monthly Revenue       53
# dtype: int64

# %% [markdown]
# ## tipos de datos

# %%
print(df.dtypes)
# Out:
# Product Name                     object
# Category                         object
# Brand                            object
# Rank                             object
# Reviews                           int64
# LQS                               int64
# Sellers                           int64
# Date First Available     datetime64[ns]
# Time in Market (days)             int64
# Buy Box Owner                    object
# Rating                          float64
# Price                           float64
# Est. Monthly Sales              float64
# Est. Monthly Revenue            float64
# dtype: object

# %%
df['Rating'] = df['Rating'].round(2)
df = df.astype({'Reviews': 'float64', 'Reviews': 'int64'})
#df['Est. Monthly Revenue'] = df['Est. Monthly Revenue'].str.replace('$', '').str.replace(',', '')
#df['Est. Monthly Sales'] = df['Est. Monthly Sales'].str.replace(',', '')
#df['Price'] = df['Price'].str.replace('$', '').str.replace(',', '')

# %%
df['Est. Monthly Sales'] = pd.to_numeric(df['Est. Monthly Sales'], errors='coerce')
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df['Est. Monthly Revenue'] = pd.to_numeric(df['Est. Monthly Revenue'], errors='coerce')

# %% [markdown]
# #### Caluclar tiempo en el mercado por producto

# %%
# Convertir la columna "Date First Available" a formato de fecha
df['Date First Available'] = pd.to_datetime(df['Date First Available'])
# Calcular cuánto tiempo ha estado en el mercado cada producto
today = datetime.today()
df['Time in Market (days)'] = (today - df['Date First Available']).dt.days

# %% [markdown]
# ### Ordenar columnas

# %%
# Si deseas reordenarlas, por ejemplo, para que 'Time in Market (days)' sea la segunda columna, haz lo siguiente:
ordered_columns = [
    'Product Name', 
    'Category', 
    'Brand', 
    'Rank', 
    'Reviews', 
    'LQS', 
    'Sellers', 
    'Date First Available', 
    'Time in Market (days)', 
    'Buy Box Owner', 
    'Rating',
    'Price', 
    'Est. Monthly Sales',
    'Est. Monthly Revenue', 
]
df = df[ordered_columns]

# %%
#pd.set_option('display.max_rows', None)
#pd.set_option('max_colwidth', None)
df
# Out:
#                                            Product Name  \
# 0     rebarstakes12inchgalvanized j hook rebar stake...
# 1     cozecube light beige bath mats for bathroom no...
# 2     purple ladybug scratch art for kids party favo...
# 3     cordless long handle replacement brush heads f...
# 4     fitwarm cheerleader dog costume sporty cheer d...
# ...                                                 ...
# 9899  inpaksa womens slippers platform mini boots sh...
# 9900  separo spandex table cover fitted rectangular ...
# 9901  hyc00 travel duffel bag sports tote gymshoulde...
# 9902  free village ice makers countertop nugget cube...
# 9903  drmtlgy brightening eye masks caffeine eye mas...
#
#                     Category           Brand    Rank  Reviews  LQS  Sellers  \
# 0          patio lawn garden          qnlong   1,381       43    6        1
# 1               home kitchen        cozecube  23,336       43    7        2
# 2                 toys games  purple ladybug   7,824        5    6        1
# 3           health household           bilim     NaN       21    5        1
# 4               pet supplies         fitwarm   5,053       30    6        1
# ...                      ...             ...     ...      ...  ...      ...
# 9899  clothing shoes jewelry         inpaksa   1,113       32    7        1
# 9900          kitchen dining          separo     524        2    7        1
# 9901  clothing shoes jewelry           hyc00  74,253       12    7        3
# 9902              appliances    free village   2,907       10    7        1
# 9903    beauty personal care         drmtlgy   1,221        4    6        2
#
#      Date First Available  Time in Market (days)  \
# 0              2023-05-27                    151
# 1              2023-03-19                    220
# 2              2023-06-28                    119
# 3              2023-06-18                    129
# 4              2023-04-03                    205
# ...                   ...                    ...
# 9899           2023-09-07                     48
# 9900           2023-06-24                    123
# 9901           2022-12-17                    312
# 9902           2023-08-15                     71
# 9903           2023-10-03                     22
#
#                                  Buy Box Owner  Rating   Price  \
# 0                                       amazon     4.8   13.89
# 1     taianshiyujiadianzishangmaoyouxiangongsi     3.9   24.99
# 2                                       amazon     5.0    8.99
# 3                                       amazon     5.0    9.99
# 4                                       amazon     4.3   14.99
# ...                                        ...     ...     ...
# 9899                                  inpaksas     3.9   45.98
# 9900                                    amazon     5.0   53.97
# 9901                          amazon warehouse     4.4   38.99
# 9902                                progressus     3.5  259.99
# 9903                                       nan     5.0   49.00
#
#       Est. Monthly Sales  Est. Monthly Revenue
# 0                 1080.0              15001.20
# 1                 1365.0              15001.35
# 2                 1669.0              15004.31
# 3                 1502.0              15004.98
# 4                 1001.0              15004.99
# ...                  ...                   ...
# 9899             11314.0             520217.72
# 9900              9648.0             520702.56
# 9901             13360.0             520906.40
# 9902              2006.0             521539.94
# 9903             10671.0             522879.00
#
# [9791 rows x 14 columns]
